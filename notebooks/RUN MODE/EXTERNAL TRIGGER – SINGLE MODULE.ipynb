# %% [markdown]
# # Single Module External Trigger Test

# %% [markdown]
# # Test Description
# This script will test the External triggering capability of proteus. In this different channels of the proteus module will get triggered from external signal generator source frequency.This script test for both triggers defined TRG1 and TRG2. This test will run for multiple sampling rate from 1GHz to 2.5GHz for all channels and from 2.5GHz to 9GHz for Channel 1 & 3 only.
#
# # Test Equipment
# 1. Tabor Proteus 9484M
# 2. Keysight Oscilloscope MSO9254A
# 3. 4 SMA to BNC Cable
# 4. Tabor WW1072 waveform generator
#
# ## Tabor WW1072 waveform generator configuration
# 1. Wave shape - Square
# 2. Frequency - 100 KHz
# 3. Amplitude - 2 Vpp
# 4. Offset - 0
#
#
# # Hardware Connection
#
#     Proteus Module    --->     Oscilloscope
#     Channel 1         --->      Channel 1
#     Channel 2         --->      Channel 2
#     Channel 3         --->      Channel 3
#     Channel 4         --->      Channel 4
#
#
#     Proteus Module    --->  Signal generator
#     TRG1 or TRG2      --->  Output of signal gen.
#
#
#
# # Test Procedure
# 1. Connect all the channels of Proteus module with the concerned channel of oscilloscope.
# 2. Connect external signal generator with TRG1 or TRG2 input.
# 3. Run the script and observe output on scope.

# %%
# Import required Libraries
import os
import sys
import tempfile
import webbrowser
srcpath = os.path.realpath('../SourceFiles')
sys.path.append(srcpath)
from teproteus import TEProteusAdmin as TepAdmin
from teproteus import TEProteusInst as TepInst
from teproteus_functions_v3 import connect
from teproteus_functions_v3 import disconnect
from teproteus_functions_v3 import set_lib_dir_path
from teproteus_functions_v3 import get_cpatured_header
from teproteus_functions_v3 import gauss_env
from teproteus_functions_v3 import iq_kernel
from teproteus_functions_v3 import pack_kernel_data
from teproteus import TEProteusAdmin, TEProteusInst
from tevisainst import TEVisaInst
#matplotlib notebook
import pyvisa as visa
import numpy as np
import time
import ipywidgets as widgets
from IPython.core.debugger import set_trace
from scipy.signal import chirp, sweep_poly
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from scipy import signal
import math
import pdb

# %%
## Connect to instrument
connection = 'LAN' #input ("Do you wish to connect via LAN/PXI/LOCAL/USB")
if connection == 'PXI':   
    # not setting this command means DLL are taken from SYS32
    #set_lib_dir_path(r'D:\Projects\ProteusAwg_Anabelle\x64\Debug') 
    # for service connection enter instrument IP
    # for PXI DLL connection enter the module slot number with Auto=False
    # when Auto=True the lowest module will be connected
    inst=connect("6",Auto=False)
    
elif connection == 'LAN':
    proteus_addr = 'TCPIP::192.90.70.22::5025::SOCKET'
    try:
        inst = TEVisaInst(proteus_addr)
    except TEVisaInst.Error as  ex1:
        print('Couldn\'t connect to \'%s\', exiting now...' % proteus_addr)
        sys.exit()
        
elif connection == 'USB':
    proteus_addr = 'USB0::0x2A8D::0x900E::MY55490134::INSTR'
    try:
        inst = TEVisaInst(proteus_addr)
    except TEVisaInst.Error as  ex1:
        print('Couldn\'t connect to \'%s\', exiting now...' % proteus_addr)
        sys.exit()
        
elif connection == 'LOCAL':
    proteus_addr = 'TCPIP::127.0.0.1::5025::SOCKET'
    try:
        inst = TEVisaInst(proteus_addr)
    except TEVisaInst.Error as  ex1:
        print('Couldn\'t connect to \'%s\', exiting now...' % proteus_addr)
        sys.exit()
        
else:
    print("Please select the conection method first")
# Get the instrument's *IDN
resp = inst.send_scpi_query('*IDN?')
print('Connected to: ' + resp)
inst.default_paranoia_level = 2
# Out:
# Connected to: Tabor Electronics,P9484M,000002232771,1.238.6 --Tabor Electronics,P9484M,000000000000,1.238.6 --slot#: 2, slot#: 4,

# %%
# Get the model:
model_name = inst.send_scpi_query('SYST:INF:MODel?')
print('Model: {0} '.format(model_name))

# Get model dependant parameters:
if model_name.startswith('P948'):
    bpp = 2
    max_dac = 65535
    wpt_type = np.uint16
    offset_factor = 1
elif model_name.startswith('P908'):
    bpp = 1
    max_dac = 255
    wpt_type = np.uint8
    offset_factor = 1
else:
    bpp = 2
    max_dac = 65535
    wpt_type = np.uint16
    offset_factor = 2
    
half_dac = max_dac / 2.0    
# Get the DAC mode (8 bits or 16 bits)

resp = inst.send_scpi_query(':SYST:INF:DAC?')
if resp == 'M0': 
    dac_mode=16 
else: dac_mode=8
   
print('DAC {0} bits'.format(dac_mode))

# Get number of channels
resp = inst.send_scpi_query(":INST:CHAN? MAX")
print("Number of channels: " + resp)
num_channels = int(resp)
# Out:
# Model: P9484M
# DAC 16 bits
# Number of channels: 4

# %%
# Several initializations ..
inst.send_scpi_cmd('*CLS; *RST')
#inst.send_scpi_cmd(':INST:CHAN 2')
inst.send_scpi_cmd(':TRAC:DEL:ALL') # Delete all segments of the programmable channel's DDR.
resp = inst.send_scpi_query(':SYST:ERR?')
print(resp)
# Get number of channels
resp = inst.send_scpi_query(":INST:CHAN? MAX")
print("Number of channels: " + resp)
num_channels = int(resp)
# Out:
# 0, no error
# Number of channels: 4

# %%
scope_addr2=  'USB0::0x2A8D::0x900E::MY55490134::INSTR'

# connect to scope via USB
try:
    resourceManager = visa.ResourceManager()   # Create a connection (session) to the instrument
    scope = resourceManager.open_resource(scope_addr2)
except visa.Error as ex2:
        print('Couldn\'t connect to \'%s\', exiting now...' % scope_addr2)
        sys.exit()
    
    
    
## scope acquisition 
# Send *IDN? and read the response
scope.write('*RST?')
scope.write('*IDN?')
idn = scope.read()
print('*IDN? returned: %s' % idn.rstrip('\n'))
# Out:
# *IDN? returned: KEYSIGHT TECHNOLOGIES,MSO9254A,MY55490134,06.40.01101

# %%
InitialFreqSampleRate = 1000
MaximumFreqSampleRate = 9000
FreqSampleRateJump = 1000

trigger_select = ['TRG1','TRG2']



    
for in_triggerselect in range(len(trigger_select)):
    print('***Testing start for Triggering input {}***\n'.format(trigger_select[in_triggerselect]))
    # print( 'Internal trigger Test for sampling rate {}MHz to {}MHz in jumps of {}MHz'.format(InitialFreqSampleRate,MaximumFreqSampleRate,FreqSampleRateJump)) 
    for FreqSampleRate in range (InitialFreqSampleRate,MaximumFreqSampleRate+FreqSampleRateJump,FreqSampleRateJump):
        inst.send_scpi_cmd(':FREQ:RAST {} MHz'.format(int(FreqSampleRate)))
        FreqSampleRate = int(FreqSampleRate)

        print('\t***Test begin for sampling rate {}MHz ***\n'.format(FreqSampleRate))

        if FreqSampleRate > 2500:
            channel_select = [1,3]
        else:
            channel_select = [1,2,3,4]

        for in_channelselect in range(len(channel_select)):
            # Select Channel & Clear it for new operation
            inst.send_scpi_cmd(':INST:CHAN {}'.format(channel_select[in_channelselect]))
            # Several initializations ..
            inst.send_scpi_cmd('*CLS; *RST')
            #inst.send_scpi_cmd(':INST:CHAN 2')
            inst.send_scpi_cmd(':TRAC:DEL:ALL') # Delete all segments of the programmable channel's DDR.
    #         resp = inst.send_scpi_query(':SYST:ERR?')
    #         print(resp)


            # Build waveforms on selected channel
            seglen = 1024
            ncycles = 1
            max_dac = 65535
            waves = [ None for _ in range(num_channels)]
            #Create Square wave
            for i in range(num_channels):
                cyclelen = seglen / ncycles

                x = np.linspace(start=0, stop=2 * np.pi * ncycles, num=seglen, endpoint=False)
                y = (np.sin(x)+1.0)*half_dac
                #y = (y <= cyclelen / 2) * max_dac
                y = np.round(y)
                y = np.clip(y, 0, max_dac)
                if dac_mode == 16:
                    waves[i] = y.astype(np.uint16)
                else:
                    waves[i] = y.astype(np.uint8)
    #         plt.plot(x,y)
    #         print("************* WAVEFORM*****************")
            # Download segments
            for ii in range(1):
                ichan = ii
                channb = ichan + channel_select[in_channelselect]
                segnum = 1
                wav = waves[0]
    #             print('Download wave to segment {} of channel {}'.format(segnum, channb))
                print('\t\t-->Test start for sampling rate {0}MHz for channel {1} for external trigger {2}'.format(FreqSampleRate,channel_select[in_channelselect],trigger_select[in_triggerselect]))
                # Select channel
                inst.send_scpi_cmd(':INST:CHAN {}'.format(channb))
                # Define segment
                inst.send_scpi_cmd(':TRAC:DEF {},{}'.format(segnum, seglen))
                # Select the segment
                inst.send_scpi_cmd(':TRAC:SEL {}'.format(segnum))
                # Increase the timeout before writing binary-data:
                inst.timeout = 30000
                # Select the segment
                cmd = ':TRAC:SEL {0}'.format(segnum)
                inst.send_scpi_cmd(cmd)
                # Send the binary-data:
                inst.write_binary_data(':TRAC:DATA', wav)
                resp = inst.send_scpi_query(':SYST:ERR?')
                resp = resp.rstrip()
                if not resp.startswith('0'):
                    print('ERROR: "{}" after writing binary values'.format(resp))
                # Play the specified segment at the selected channel:
                cmd = ':SOUR:FUNC:MODE:SEGM {}'.format(segnum)
                inst.send_scpi_cmd(cmd)
                # Turn on the output of the selected channel:
                inst.send_scpi_cmd(':OUTP ON')
                resp = inst.send_scpi_query(':SYST:ERR?')
    #             print(resp)
    #         print()
    #         resp = inst.send_scpi_query(':SYST:ERR?')
    #         print(resp)


            # Read peak_peak_volt for sine wave generated
            scope.write('*CLS;:DISPlay:CGRade:LEVels ')
            scope.write('AUTOscale')
            time.sleep(10)
            scope.write(':MEASure:VPP CHANnel{}'.format(channel_select[in_channelselect]))
            time.sleep(2)
            scope.write(':MEASure:RESults?')
            result = scope.read()
            peak_peak_volt1= float(result.split(',')[1])
#             print(peak_peak_volt1)



            # Make contineous mode OFF to turn trigger mode ON
            # Read peak_peak_volt again, expected voltage level is around zero as contineous mode is off
            inst.send_scpi_cmd(':INIT:CONT OFF')
            scope.write(':CHANnel{}:DISPlay ON'.format(channel_select[in_channelselect]))
            inst.send_scpi_cmd(':OUTP ON')
            # Get the status of contineous mode 1= ON, 0=OFF
            resp = inst.send_scpi_query(":INIT:CONT?")
    #         print("State of contineous mode is : " + resp)
            scope.write('*CLS;:DISPlay:CGRade:LEVels ')
    #       scope.write('AUTOscale')
            time.sleep(5)    
            scope.write(':MEASure:VPP CHANnel{}'.format(channel_select[in_channelselect]))
            time.sleep(2)
            scope.write(':MEASure:RESults?')
            result = scope.read()
            peak_peak_volt2= float(result.split(',')[1])
#             print(peak_peak_volt2)



            # Enable the internal trigger for selected channel
            # Enaable the Trigger source NONE|TRG1|TRG2|TRG3|TRG4|TRG5|TRG6|INTernal|CPU|FBTRg|HWControl
            inst.send_scpi_cmd(':TRIG:SOUR:ENAB {}'.format(trigger_select[in_triggerselect]))
            # Enable the triggering source
            resp = inst.send_scpi_query(":TRIG:SOUR:ENAB?")
    #         print("Triggering source " + resp + " is Enabled")
            # Activate the triggering source 1= ON, 0=OFF
            inst.send_scpi_cmd(':TRIG:ACTIVE:SEL {}'.format(trigger_select[in_triggerselect]))
            resp = inst.send_scpi_query(":TRIG:ACTIVE:SEL?")
            inst.send_scpi_cmd(':TRIG:STAT ON')


            # Wait for internal trigger pulse to be appear
            # After it appear adjust the Verticle and Horizontal scaling so that voltage level can be read
            time.sleep(5)
            scope.write(':CHANnel{}:PROBe 1.0'.format(channel_select[in_channelselect]))
            scope.write(':CHANnel{}:SCALe 100E-3'.format(channel_select[in_channelselect]))
            scope.write(':CHANnel{}:OFFSet 0.0'.format(channel_select[in_channelselect]))
            scope.write(':TIMebase:SCALe 5E-6')
            scope.write(':TRIGger:MODE EDGE')
            scope.write(':TRIGger:EDGE:SOURce CHANnel{}'.format(channel_select[in_channelselect]))
            scope.write(':TRIGger:LEVel CHANnel{},120e-3'.format(channel_select[in_channelselect]))
            scope.write(':MEASure:PERiod? CHANnel{}'.format(channel_select[in_channelselect]))
            resualt = scope.read()
            measured_period = float(resualt.split(',')[0])
#             print(measured_period)
            scope.write(':MEASure:VPP CHANnel{}'.format(channel_select[in_channelselect]))
            time.sleep(2)
            scope.write(':MEASure:RESults?')
            result = scope.read()
            peak_peak_volt3= float(result.split(',')[1])
#             print(peak_peak_volt3)



            # Test for Verticle and Horizontal parameters for decision that was captured on different level
            if abs(peak_peak_volt1-peak_peak_volt3)<120e-3 and peak_peak_volt2< 120e-03:
                if 9.5e-6 < (measured_period) < 10.5e-6:
                    print('\t\t-->Test  Pass for sampling rate {0}MHz for channel {1} for external trigger {2}\n'.format(FreqSampleRate,channel_select[in_channelselect],trigger_select[in_triggerselect]))
                else:
                    print('\t\t-->Test  Fail for sampling rate {0}MHz for channel {1} for external trigger {2}\n'.format(FreqSampleRate,channel_select[in_channelselect],trigger_select[in_triggerselect]))
            else:
                print('\t\t-->Test  Fail for sampling rate {0}MHz for channel {1} for external trigger {2}\n'.format(FreqSampleRate,channel_select[in_channelselect],trigger_select[in_triggerselect]))
            # Clear the display for next operation
            for i in range(4):
                scope.write(':CHANnel{}:DISPlay OFF'.format(i+1))
                inst.send_scpi_cmd(':INST:CHAN {}'.format(channel_select[in_channelselect]))
                inst.send_scpi_cmd(':TRIG:STAT OFF')


        print('\t***Test completed for sampling rate {}MHz***\n'.format(FreqSampleRate))


    print('***All Test Completed for external trigger {0}***\n'.format(trigger_select[in_triggerselect]))
    if trigger_select[in_triggerselect] == 'TRG1':
        print('Please connect external signal generator with TRG2 input and Press Enter \n')
        input()
    else:
        print('Test Completed for all sampling on each channel for all possible external triggers')
        


# close inst connection
inst.close_instrument()
disconnect()

# Close the connection to the instrument
scope.close()
resourceManager.close()
# Out:
# ***Testing start for Triggering input TRG1***
#
# 	***Test begin for sampling rate 1000MHz ***
#
# 		-->Test start for sampling rate 1000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 1000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 1000MHz for channel 2 for external trigger TRG1
# 		-->Test  Pass for sampling rate 1000MHz for channel 2 for external trigger TRG1
#
# 		-->Test start for sampling rate 1000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 1000MHz for channel 3 for external trigger TRG1
#
# 		-->Test start for sampling rate 1000MHz for channel 4 for external trigger TRG1
# 		-->Test  Pass for sampling rate 1000MHz for channel 4 for external trigger TRG1
#
# 	***Test completed for sampling rate 1000MHz***
#
# 	***Test begin for sampling rate 2000MHz ***
#
# 		-->Test start for sampling rate 2000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 2000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 2000MHz for channel 2 for external trigger TRG1
# 		-->Test  Pass for sampling rate 2000MHz for channel 2 for external trigger TRG1
#
# 		-->Test start for sampling rate 2000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 2000MHz for channel 3 for external trigger TRG1
#
# 		-->Test start for sampling rate 2000MHz for channel 4 for external trigger TRG1
# 		-->Test  Pass for sampling rate 2000MHz for channel 4 for external trigger TRG1
#
# 	***Test completed for sampling rate 2000MHz***
#
# 	***Test begin for sampling rate 3000MHz ***
#
# 		-->Test start for sampling rate 3000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 3000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 3000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 3000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 3000MHz***
#
# 	***Test begin for sampling rate 4000MHz ***
#
# 		-->Test start for sampling rate 4000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 4000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 4000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 4000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 4000MHz***
#
# 	***Test begin for sampling rate 5000MHz ***
#
# 		-->Test start for sampling rate 5000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 5000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 5000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 5000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 5000MHz***
#
# 	***Test begin for sampling rate 6000MHz ***
#
# 		-->Test start for sampling rate 6000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 6000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 6000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 6000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 6000MHz***
#
# 	***Test begin for sampling rate 7000MHz ***
#
# 		-->Test start for sampling rate 7000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 7000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 7000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 7000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 7000MHz***
#
# 	***Test begin for sampling rate 8000MHz ***
#
# 		-->Test start for sampling rate 8000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 8000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 8000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 8000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 8000MHz***
#
# 	***Test begin for sampling rate 9000MHz ***
#
# 		-->Test start for sampling rate 9000MHz for channel 1 for external trigger TRG1
# 		-->Test  Pass for sampling rate 9000MHz for channel 1 for external trigger TRG1
#
# 		-->Test start for sampling rate 9000MHz for channel 3 for external trigger TRG1
# 		-->Test  Pass for sampling rate 9000MHz for channel 3 for external trigger TRG1
#
# 	***Test completed for sampling rate 9000MHz***
#
# ***All Test Completed for external trigger TRG1***
#
# Please connect external signal generator with TRG2 input and Press Enter
#
#
# ***Testing start for Triggering input TRG2***
#
# 	***Test begin for sampling rate 1000MHz ***
#
# 		-->Test start for sampling rate 1000MHz for channel 1 for external trigger TRG2
# 		-->Test  Pass for sampling rate 1000MHz for channel 1 for external trigger TRG2
#
# 		-->Test start for sampling rate 1000MHz for channel 2 for external trigger TRG2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17944\3390870582.py in <module>
#      93             scope.write('*CLS;:DISPlay:CGRade:LEVels ')
#      94             scope.write('AUTOscale')
# ---> 95             time.sleep(10)
#      96             scope.write(':MEASure:VPP CHANnel{}'.format(channel_select[in_channelselect]))
#      97             time.sleep(2)
#
# KeyboardInterrupt:
